# %%
from pyspark import SparkConf, SparkContext

# %%
conf = SparkConf().setMaster("local").setAppName("freindsByAge")

# %%
sc = SparkContext(conf=conf)
# Out:
# 22/08/02 13:48:29 WARN Utils: Your hostname, Gals-MacBook-Pro-2.local resolves to a loopback address: 127.0.0.1; using 192.168.68.104 instead (on interface en0)
# 22/08/02 13:48:29 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# WARNING: An illegal reflective access operation has occurred
# WARNING: Illegal reflective access by org.apache.spark.unsafe.Platform (file:/Users/galrabin/opt/anaconda3/envs/spark-course/lib/python3.10/site-packages/pyspark/jars/spark-unsafe_2.12-3.1.2.jar) to constructor java.nio.DirectByteBuffer(long,int)
# WARNING: Please consider reporting this to the maintainers of org.apache.spark.unsafe.Platform
# WARNING: Use --illegal-access=warn to enable warnings of further illegal reflective access operations
# WARNING: All illegal access operations will be denied in a future release
# 22/08/02 13:48:29 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# ...

# %%
lines = sc.textFile("/Users/galrabin/projects/courses/spark/fakefriends.csv")

# %%
totalsByAge = lines.map(lambda x: (x, 1))

# %%
totalsByAge.foreach(lambda x: print(x))
# Out:
# ('0,Will,33,385', 1)
# ('1,Jean-Luc,26,2', 1)
# ('2,Hugh,55,221', 1)
# ('3,Deanna,40,465', 1)
# ('4,Quark,68,21', 1)
# ('5,Weyoun,59,318', 1)
# ('6,Gowron,37,220', 1)
# ('7,Will,54,307', 1)
# ('8,Jadzia,38,380', 1)
# ('9,Hugh,27,181', 1)
# ('10,Odo,53,191', 1)
# ('11,Ben,57,372', 1)
# ('12,Keiko,54,253', 1)
# ('13,Jean-Luc,56,444', 1)
# ('14,Hugh,43,49', 1)
# ('15,Rom,36,49', 1)
# ('16,Weyoun,22,323', 1)
# ('17,Odo,35,13', 1)
# ('18,Jean-Luc,45,455', 1)
# ('19,Geordi,60,246', 1)
# ('20,Odo,67,220', 1)
# ('21,Miles,19,268', 1)
# ('22,Quark,30,72', 1)
# ('23,Keiko,51,271', 1)
# ('24,Julian,25,1', 1)
# ('25,Ben,21,445', 1)
# ('26,Julian,22,100', 1)
# ('27,Leeta,42,363', 1)
# ('28,Martok,49,476', 1)
# ('29,Nog,48,364', 1)
# ('30,Keiko,50,175', 1)
# ('31,Miles,39,161', 1)
# ('32,Nog,26,281', 1)
# ('33,Dukat,53,197', 1)
# ('34,Jean-Luc,43,249', 1)
# ('35,Beverly,27,305', 1)
# ('36,Kasidy,32,81', 1)
# ('37,Geordi,58,21', 1)
# ('38,Deanna,64,65', 1)
# ('39,Morn,31,192', 1)
# ...
